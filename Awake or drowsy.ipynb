# %%
# !pip3 install torch==1.8.2 torchvision==0.9.2 torchaudio===0.8.2 --extra-index-url https://download.pytorch.org/whl/lts/1.8/cpu
# Out:
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/lts/1.8/cpu
# ...
#   Attempting uninstall: torch
#     Found existing installation: torch 1.12.0
#     Uninstalling torch-1.12.0:
#       Successfully uninstalled torch-1.12.0
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.13.0
#     Uninstalling torchvision-0.13.0:
#       Successfully uninstalled torchvision-0.13.0
#   Attempting uninstall: torchaudio
#     Found existing installation: torchaudio 0.12.0
#     Uninstalling torchaudio-0.12.0:
#       Successfully uninstalled torchaudio-0.12.0
# ...

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# fatal: destination path 'yolov5' already exists and is not an empty directory.

# %%
# !cd yolov5

# %%
# !pip freeze requirements.txt
# Out:
# -qdm @ file:///tmp/build/80754af9/tqdm_1615925068909/work
# alabaster @ file:///home/ktietz/src/ci/alabaster_1611921544520/work
# anaconda-client==1.7.2
# anaconda-navigator==2.0.3
# anaconda-project @ file:///tmp/build/80754af9/anaconda-project_1610472525955/work
# anyio @ file:///C:/ci/anyio_1620153418380/work/dist
# appdirs==1.4.4
# argh==0.26.2
# argon2-cffi @ file:///C:/ci/argon2-cffi_1613037959010/work
# asn1crypto @ file:///tmp/build/80754af9/asn1crypto_1596577642040/work
# astroid @ file:///C:/ci/astroid_1613501047216/work
# astropy @ file:///C:/ci/astropy_1617745647203/work
# async-generator @ file:///home/ktietz/src/ci/async_generator_1611927993394/work
# atomicwrites==1.4.0
# attrs @ file:///tmp/build/80754af9/attrs_1604765588209/work
# audioread==2.1.9
# autopep8 @ file:///tmp/build/80754af9/autopep8_1615918855173/work
# Babel @ file:///tmp/build/80754af9/babel_1607110387436/work
# backcall @ file:///home/ktietz/src/ci/backcall_1611930011877/work
# ...

# %%
import torch
from matplotlib import pyplot as plt
import numpy as np
import cv2

# %%
model = torch.hub.load('ultralytics/yolov5', 'yolov5s')
# Out:
# Using cache found in C:\Users\shubhisha/.cache\torch\hub\ultralytics_yolov5_master
# YOLOv5  2022-8-2 Python-3.8.8 torch-1.8.2+cpu CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# Adding AutoShape...

# %%
img='https://media.istockphoto.com/photos/aerial-view-of-cars-in-traffic-picture-id159406920?k=20&m=159406920&s=170667a&w=0&h=DBBrPv4hXOi12yMki0WgMfTXLPJDJl7GH_8q9FtCJyg='

# %%
results = model(img)
results.print()
# Out:
# image 1/1: 338x507 25 cars
# Speed: 595.4ms pre-process, 681.2ms inference, 115.2ms NMS per image at shape (1, 3, 448, 640)

# %%
# %matplotlib inline 
plt.imshow(np.squeeze(results.render()))
plt.show()

# %%
# !pip install -U numpy
# Out:
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.20.1
#     Uninstalling numpy-1.20.1:
#       Successfully uninstalled numpy-1.20.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# scipy 1.6.2 requires numpy<1.23.0,>=1.16.5, but you have numpy 1.23.1 which is incompatible.
# ...

# %%
results.render()
# Out:
# [array([[[187, 169, 149],
#          [182, 159, 128],
#          [168, 135, 100],
#          ...,
#          [109,  67,   7],
#          [109,  67,   7],
#          [108,  66,   6]],
#
#         [[145, 106,  65],
#          [171, 129,  89],
#          [161, 116,  74],
#          ...,
#          [114,  69,   4],
#          [113,  69,   6],
#          [112,  68,   5]],
#
#         [[138,  92,  32],
#          [145,  97,  48],
#          [148, 100,  52],
#          ...,
#          [121,  74,   6],
#          [122,  75,   7],
#          [122,  74,   8]],
#
#         ...,
#
#         [[ 22,  11,   5],
#          [ 22,  11,   5],
#          [ 22,  11,   5],
#          ...,
#          [255, 112,  31],
#          [255, 112,  31],
#          [255, 112,  31]],
#
#         [[ 25,  11,   8],
#          [ 25,  11,   8],
#          [ 26,  13,   7],
#          ...,
#          [255, 112,  31],
#          [255, 112,  31],
#          [255, 112,  31]],
#
#         [[ 26,  12,   9],
# ...

# %%
cap = cv2.VideoCapture(0)
while cap.isOpened():
    ret, frame = cap.read()
    
    results = model(frame)
    
    cv2.imshow('YOLO', np.squeeze(results.render()))
    
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()

# %%
import uuid   # Unique identifier
import os
import time

# %%
IMAGES_PATH = os.path.join('data', 'images') #/data/images
labels = ['awake', 'drowsy']
number_imgs = 10

# %%
cap = cv2.VideoCapture(0)

for label in labels:
    print('Collecting images for {}'.format(label))
    time.sleep(5)
    
    for img_num in range(number_imgs):
        print('Collecting images for {}, image number {}'.format(label, img_num))
        
        # Webcam feed
        ret, frame = cap.read()
        
        imgname = os.path.join(IMAGES_PATH, label+'.'+str(uuid.uuid1())+'.jpg')
        
        
        cv2.imwrite(imgname, frame)
        
       
        cv2.imshow('Image Collection', frame)
        
        
        time.sleep(2)
        
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
cap.release()
cv2.destroyAllWindows()

# %%
print(os.path.join(IMAGES_PATH, labels[0]+'.'+str(uuid.uuid1())+'.jpg'))
# Out:
# hello\world\awake.c50e8444-118f-11ed-b464-50e0850d0164.jpg

# %%
for label in labels:
    print('Collecting images for {}'.format(label))
    
    for img_num in range(number_imgs):
        print('Collecting images for {}, image number {}'.format(label, img_num))
        imgname = os.path.join(IMAGES_PATH, label+'.'+str(uuid.uuid1())+'.jpg')
        print(imgname)
# Out:
# ...
# hello\world\awake.c3912af3-118f-11ed-9729-50e0850d0164.jpg
# ...
# hello\world\awake.c3912af4-118f-11ed-908a-50e0850d0164.jpg
# ...
# hello\world\awake.c3912af5-118f-11ed-951d-50e0850d0164.jpg
# ...
# hello\world\awake.c3912af6-118f-11ed-b41d-50e0850d0164.jpg
# ...
# hello\world\awake.c3912af7-118f-11ed-a978-50e0850d0164.jpg
# ...
# hello\world\awake.c3912af8-118f-11ed-b1b4-50e0850d0164.jpg
# ...
# hello\world\awake.c3912af9-118f-11ed-a52a-50e0850d0164.jpg
# ...
# hello\world\awake.c3912afa-118f-11ed-b9f7-50e0850d0164.jpg
# ...
# hello\world\awake.c3912afb-118f-11ed-b589-50e0850d0164.jpg
# ...
# hello\world\awake.c3912afc-118f-11ed-9430-50e0850d0164.jpg
# ...
# hello\world\drowsy.c3912afd-118f-11ed-9c71-50e0850d0164.jpg
# ...
# hello\world\drowsy.c3919e6c-118f-11ed-b9ea-50e0850d0164.jpg
# ...
# hello\world\drowsy.c3919e6d-118f-11ed-b8d4-50e0850d0164.jpg
# ...
# hello\world\drowsy.c3919e6e-118f-11ed-803b-50e0850d0164.jpg
# ...
# hello\world\drowsy.c3919e6f-118f-11ed-b69d-50e0850d0164.jpg
# ...
# hello\world\drowsy.c3919e70-118f-11ed-9c3d-50e0850d0164.jpg
# ...

# %%
# !git clone https://github.com/tzutalin/labelImg
# Out:
# Cloning into 'labelImg'...
# fatal: unable to access 'https://github.com/tzutalin/labelImg/': Failed to connect to github.com port 443 after 21076 ms: Timed out

# %%
# !git clone https://github.com/tzutalin/labelImg
# Out:
# fatal: destination path 'labelImg' already exists and is not an empty directory.

# %%
# !pip install pyqt5 lxml --upgrade
# !cd labelImg && pyrcc5 -o libs/resources.py resources.qrc

# %%
# !cd yolov5 && python train.py --img 320 --batch 16 --epochs 500 --data dataset.yaml --weights yolov5s.pt --workers 2

# %%
model = torch.hub.load('ultralytics/yolov5', 'custom', path='yolov5/runs/train/exp19/weights/last.pt', force_reload=True)
# Out:
# Downloading: "https://github.com/ultralytics/yolov5/archive/master.zip" to C:\Users\shubhisha/.cache\torch\hub\master.zip
# YOLOv5  2022-8-3 Python-3.8.8 torch-1.8.2+cpu CPU
#
# Fusing layers...
# Model summary: 213 layers, 7055974 parameters, 0 gradients
# Adding AutoShape...

# %%
img = os.path.join('data', 'images', 'drowsy.ea7bf45a-118f-11ed-85b3-50e0850d0164.jpg')

# %%
results = model(img)

# %%
results.print()
# Out:
# image 1/1: 480x640 1 drowsy
# Speed: 9.0ms pre-process, 187.9ms inference, 0.0ms NMS per image at shape (1, 3, 480, 640)

# %%
# %matplotlib inline 
plt.imshow(np.squeeze(results.render()))
plt.show()

# %%
cap = cv2.VideoCapture(0)
while cap.isOpened():
    ret, frame = cap.read()
    
    # Make detections 
    results = model(frame)
    
    cv2.imshow('YOLO', np.squeeze(results.render()))
    
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()
